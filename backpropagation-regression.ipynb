# %%
import numpy as np
import pandas as pd

# %%
df  = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa', 'profile_score', 'lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):
  np.random.seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1, L):
    parameters['W' +str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
    parameters['b' +str(l)] = np.zeros((layer_dims[l], 1))

  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forword(A_prev, W, b):
  Z = np.dot(W.T, A_prev) + b
  return Z

# %%
def L_Layer_forword(X, parameters):
  A = X
  L = len(parameters) // 2

  for l in range(1, L+1):
    A_prev = A
    W1 = parameters['W' +str(l)]
    b1 = parameters['b' +str(l)]
    # print("A" + str(l-1)+": ", A_prev)
    # print("W"+str(l)+": ",W1)
    # print("b"+str(l)+": ",b1)
    # print("--"*20)

    A = linear_forword(A_prev, W1, b1)
    # print("A"+str(l)+": ",A)
    # print("**"*20)

  return A, A_prev

# %%
X = df[['cgpa','profile_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]

parameters = initialize_parameters([2,2,1])

# %%
y_hat, A1 = L_Layer_forword(X, parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************

# %%
y_hat = y_hat[0][0]
y_hat
# Out:
# 0.32000000000000006

# %%
A1
# Out:
# array([[1.6],
#        [1.6]])

# %%
loss = (y-0.32)**2
loss
# Out:
# 13.5424

# %%
def update_parameters(parameters, y, y_hat, A1, X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y-y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y-y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001 * 2 * (y-y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][0][0]* X[0][0])
  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][0][0]* X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][0][0])

  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y-y_hat)* parameters['W2'][1][0]* X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y-y_hat)* parameters['W2'][1][0]* X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][1][0])

# %%
X = df[['cgpa','profile_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]

# %%
update_parameters(parameters, y, y_hat, A1, X)

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.00736]])}

# %%
X = df[['cgpa','profile_score']].values[3].reshape(2,1)
y = df[['lpa']].values[3][0]

y_hat, A1 = L_Layer_forword(X, parameters)
# Out:
# A0:  [[ 5]
#  [12]]
# W1:  [[0.12459806 0.12459806]
#  [0.13347329 0.13347329]]
# b1:  [[0.00362946]
#  [0.00362946]]
# ----------------------------------------
# A1:  [[2.22829927]
#  [2.22829927]]
# ****************************************
# A1:  [[2.22829927]
#  [2.22829927]]
# W2:  [[0.14802989]
#  [0.14802989]]
# b2:  [[0.02759933]]
# ----------------------------------------
# A2:  [[0.68730913]]
# ****************************************

# %%
update_parameters(parameters, y, y_hat, A1, X)
# Out:
# <ipython-input-52-77addd16ed35>:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y-y_hat)*A1[0][0])
# <ipython-input-52-77addd16ed35>:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y-y_hat)*A1[1][0])
# <ipython-input-52-77addd16ed35>:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001 * 2 * (y-y_hat))
# <ipython-input-52-77addd16ed35>:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][0][0]* X[0][0])
# <ipython-input-52-77addd16ed35>:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][0][0]* X[1][0])
# <ipython-input-52-77addd16ed35>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][0][0])
# <ipython-input-52-77addd16ed35>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y-y_hat)* parameters['W2'][1][0]* X[0][0])
# <ipython-input-52-77addd16ed35>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y-y_hat)* parameters['W2'][1][0]* X[1][0])
# <ipython-input-52-77addd16ed35>:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y-y_hat)* parameters['W2'][1][0])

# %%
parameters
# Out:
# {'W1': array([[0.13571869, 0.13571869],
#         [0.1601628 , 0.1601628 ]]),
#  'b1': array([[0.00585359],
#         [0.00585359]]),
#  'W2': array([[0.17616302],
#         [0.17616302]]),
#  'b2': array([[0.04022471]])}

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 200

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Parameter initialization


    y_hat,A1 = L_Layer_forword(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# Epoch -  1 Loss -  26.249691774703265
# Epoch -  2 Loss -  19.19634375189233
# Epoch -  3 Loss -  9.702531836210806
# Epoch -  4 Loss -  3.0274162602080916
# Epoch -  5 Loss -  1.0597082587765176
# Epoch -  6 Loss -  0.8771341125393668
# Epoch -  7 Loss -  0.9043847287039875
# Epoch -  8 Loss -  0.9098910885136656
# Epoch -  9 Loss -  0.8984198234465794
# Epoch -  10 Loss -  0.8811710500481387
# Epoch -  11 Loss -  0.8624558353005285
# Epoch -  12 Loss -  0.843633387420633
# Epoch -  13 Loss -  0.8251023933883717
# Epoch -  14 Loss -  0.8069696299763118
# Epoch -  15 Loss -  0.7892553732258184
# Epoch -  16 Loss -  0.7719548957951685
# Epoch -  17 Loss -  0.7550566989371805
# Epoch -  18 Loss -  0.7385478707457893
# Epoch -  19 Loss -  0.7224156296949529
# Epoch -  20 Loss -  0.7066477418855522
# Epoch -  21 Loss -  0.6912326082242793
# Epoch -  22 Loss -  0.6761592569226377
# Epoch -  23 Loss -  0.6614173106705683
# Epoch -  24 Loss -  0.6469969487407259
# Epoch -  25 Loss -  0.6328888697866473
# Epoch -  26 Loss -  0.6190842568379603
# Epoch -  27 Loss -  0.6055747447579207
# Epoch -  28 Loss -  0.5923523900813462
# Epoch -  29 Loss -  0.579409643064681
# Epoch -  30 Loss -  0.5667393217688214
# Epoch -  31 Loss -  0.5543345880049212
# Epoch -  32 Loss -  0.5421889249875788
# Epoch -  33 Loss -  0.5302961165542049
# Epoch -  34 Loss -  0.5186502278227575
# Epoch -  35 Loss -  0.5072455871721041
# Epoch -  36 Loss -  0.49607676944016593
# Epoch -  37 Loss -  0.4851385802447776
# Epoch -  38 Loss -  0.47442604134099
# Epoch -  39 Loss -  0.4639343769363908
# Epoch -  40 Loss -  0.4536590008931943
# Epoch -  41 Loss -  0.44359550475219195
# Epoch -  42 Loss -  0.4337396465194547
# Epoch -  43 Loss -  0.4240873401618642
# Epoch -  44 Loss -  0.4146346457622882
# Epoch -  45 Loss -  0.40537776028938
# Epoch -  46 Loss -  0.3963130089409434
# Epoch -  47 Loss -  0.38743683702315146
# Epoch -  48 Loss -  0.3787458023311312
# Epoch -  49 Loss -  0.37023656799925286
# Epoch -  50 Loss -  0.3619058957920196
# Epoch -  51 Loss -  0.3537506398088146
# Epoch -  52 Loss -  0.345767740577852
# Epoch -  53 Loss -  0.3379542195166205
# Epoch -  54 Loss -  0.3303071737378204
# Epoch -  55 Loss -  0.3228237711813819
# Epoch -  56 Loss -  0.315501246054565
# Epoch -  57 Loss -  0.30833689456345276
# Epoch -  58 Loss -  0.3013280709202916
# Epoch -  59 Loss -  0.29447218361219735
# Epoch -  60 Loss -  0.28776669191772347
# Epoch -  61 Loss -  0.2812091026586221
# Epoch -  62 Loss -  0.2747969671749219
# Epoch -  63 Loss -  0.2685278785121787
# Epoch -  64 Loss -  0.262399468810337
# Epoch -  65 Loss -  0.2564094068842931
# Epoch -  66 Loss -  0.2505553959867041
# Epoch -  67 Loss -  0.24483517174411118
# Epoch -  68 Loss -  0.23924650025783167
# Epoch -  69 Loss -  0.2337871763615021
# Epoch -  70 Loss -  0.2284550220274696
# Epoch -  71 Loss -  0.22324788491457093
# Epoch -  72 Loss -  0.218163637050125
# Epoch -  73 Loss -  0.21320017363921467
# Epoch -  74 Loss -  0.20835541199460972
# Epoch -  75 Loss -  0.2036272905808634
# Epoch -  76 Loss -  0.19901376816636146
# Epoch -  77 Loss -  0.19451282307728032
# Epoch -  78 Loss -  0.1901224525475777
# Epoch -  79 Loss -  0.18584067215933261
# Epoch -  80 Loss -  0.18166551536791192
# Epoch -  81 Loss -  0.17759503310656727
# Epoch -  82 Loss -  0.17362729346525418
# Epoch -  83 Loss -  0.16976038143858488
# Epoch -  84 Loss -  0.16599239873798244
# Epoch -  85 Loss -  0.1623214636632285
# Epoch -  86 Loss -  0.15874571102875115
# Epoch -  87 Loss -  0.15526329214013865
# Epoch -  88 Loss -  0.15187237481648605
# Epoch -  89 Loss -  0.14857114345432826
# Epoch -  90 Loss -  0.14535779912907185
# Epoch -  91 Loss -  0.14223055972994136
# Epoch -  92 Loss -  0.13918766012463418
# Epoch -  93 Loss -  0.1362273523499948
# Epoch -  94 Loss -  0.1333479058251802
# Epoch -  95 Loss -  0.13054760758392617
# Epoch -  96 Loss -  0.12782476252267172
# Epoch -  97 Loss -  0.12517769366146134
# Epoch -  98 Loss -  0.12260474241466512
# Epoch -  99 Loss -  0.12010426886873359
# Epoch -  100 Loss -  0.11767465206435011
# Epoch -  101 Loss -  0.11531429028047953
# Epoch -  102 Loss -  0.11302160131797505
# Epoch -  103 Loss -  0.11079502278055459
# Epoch -  104 Loss -  0.10863301235110073
# Epoch -  105 Loss -  0.10653404806139014
# Epoch -  106 Loss -  0.10449662855349859
# Epoch -  107 Loss -  0.10251927333128212
# Epoch -  108 Loss -  0.10060052300046102
# Epoch -  109 Loss -  0.09873893949598424
# Epoch -  110 Loss -  0.09693310629548545
# Epoch -  111 Loss -  0.09518162861775967
# Epoch -  112 Loss -  0.09348313360534122
# Epoch -  113 Loss -  0.0918362704903694
# Epoch -  114 Loss -  0.09023971074305305
# Epoch -  115 Loss -  0.08869214820216101
# Epoch -  116 Loss -  0.08719229918708622
# Epoch -  117 Loss -  0.08573890259111154
# Epoch -  118 Loss -  0.08433071995563703
# Epoch -  119 Loss -  0.0829665355252044
# Epoch -  120 Loss -  0.08164515628324463
# Epoch -  121 Loss -  0.08036541196857537
# Epoch -  122 Loss -  0.07912615507273923
# Epoch -  123 Loss -  0.07792626081835857
# Epoch -  124 Loss -  0.07676462711873834
# Epoch -  125 Loss -  0.07564017451903599
# Epoch -  126 Loss -  0.07455184611935282
# Epoch -  127 Loss -  0.07349860748016707
# Epoch -  128 Loss -  0.07247944651057628
# Epoch -  129 Loss -  0.07149337333985789
# Epoch -  130 Loss -  0.07053942017289717
# Epoch -  131 Loss -  0.06961664113006895
# Epoch -  132 Loss -  0.06872411207217878
# Epoch -  133 Loss -  0.0678609304111142
# Epoch -  134 Loss -  0.06702621490685211
# Epoch -  135 Loss -  0.06621910545151143
# Epoch -  136 Loss -  0.06543876284112946
# Epoch -  137 Loss -  0.06468436853587928
# Epoch -  138 Loss -  0.06395512440941438
# Epoch -  139 Loss -  0.06325025248806951
# Epoch -  140 Loss -  0.06256899468061158
# Epoch -  141 Loss -  0.06191061249926637
# Epoch -  142 Loss -  0.06127438677270481
# Epoch -  143 Loss -  0.060659617351701646
# Epoch -  144 Loss -  0.060065622808138416
# Epoch -  145 Loss -  0.05949174012803675
# Epoch -  146 Loss -  0.05893732439926835
# Epoch -  147 Loss -  0.05840174849460797
# Epoch -  148 Loss -  0.05788440275073296
# Epoch -  149 Loss -  0.05738469464380617
# Epoch -  150 Loss -  0.05690204846221563
# Epoch -  151 Loss -  0.05643590497705383
# Epoch -  152 Loss -  0.05598572111088724
# Epoch -  153 Loss -  0.05555096960534624
# Epoch -  154 Loss -  0.05513113868804029
# Epoch -  155 Loss -  0.05472573173929665
# Epoch -  156 Loss -  0.05433426695917626
# Epoch -  157 Loss -  0.053956277035214044
# Epoch -  158 Loss -  0.05359130881130194
# Epoch -  159 Loss -  0.05323892295811129
# Epoch -  160 Loss -  0.052898693645430865
# Epoch -  161 Loss -  0.05257020821676906
# Epoch -  162 Loss -  0.052253066866551866
# Epoch -  163 Loss -  0.05194688232022625
# Epoch -  164 Loss -  0.051651279517554695
# Epoch -  165 Loss -  0.051365895299361426
# Epoch -  166 Loss -  0.05109037809799197
# Epoch -  167 Loss -  0.05082438763168924
# Epoch -  168 Loss -  0.05056759460311223
# Epoch -  169 Loss -  0.05031968040217659
# Epoch -  170 Loss -  0.05008033681338493
# Epoch -  171 Loss -  0.04984926572780535
# Epoch -  172 Loss -  0.04962617885982978
# Epoch -  173 Loss -  0.049410797468834554
# Epoch -  174 Loss -  0.049202852085840354
# Epoch -  175 Loss -  0.049002082245274754
# Epoch -  176 Loss -  0.04880823622189788
# Epoch -  177 Loss -  0.04862107077296279
# Epoch -  178 Loss -  0.0484403508856572
# Epoch -  179 Loss -  0.048265849529863424
# Epoch -  180 Loss -  0.04809734741626319
# Epoch -  181 Loss -  0.04793463275980545
# Epoch -  182 Loss -  0.04777750104853476
# Epoch -  183 Loss -  0.04762575481778641
# Epoch -  184 Loss -  0.04747920342972764
# Epoch -  185 Loss -  0.0473376628582281
# Epoch -  186 Loss -  0.047200955479025565
# Epoch -  187 Loss -  0.04706890986516149
# Epoch -  188 Loss -  0.04694136058762866
# Epoch -  189 Loss -  0.046818148021196195
# Epoch -  190 Loss -  0.04669911815535223
# Epoch -  191 Loss -  0.04658412241030245
# Epoch -  192 Loss -  0.04647301745796653
# Epoch -  193 Loss -  0.046365665047897346
# Epoch -  194 Loss -  0.04626193183806043
# Epoch -  195 Loss -  0.046161689230390476
# Epoch -  196 Loss -  0.046064813211050215
# Epoch -  197 Loss -  0.04597118419531053
# Epoch -  198 Loss -  0.04588068687697004
# Epoch -  199 Loss -  0.04579321008222456
# Epoch -  200 Loss -  0.04570864662791014
# {'W1': array([[-0.10605746, -0.10605746],
#         [ 0.58886067,  0.58886067]]),
#  'b1': array([[0.01461752],
#         [0.01461752]]),
#  'W2': array([[0.53548083],
#         [0.53548083]]),
#  'b2': array([[0.08202785]])}

# %%
X = df[['cgpa', 'profile_score']].values[3].reshape(2,1)
y_hat,A1 = L_Layer_forword(X,parameters)
y_hat
# Out:
# array([[7.09753168]])
